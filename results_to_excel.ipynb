# %%
import os
import json
import pandas as pd

METRICS_ORDER = ['HR@1', 'HR@5', 'HR@10', 'HR@20', 'HR@50','NDCG@5', 'NDCG@10', 
                 'NDCG@20', 'NDCG@50','MRR@5', 'MRR@10', 'MRR@20', 'MRR@50',]

def parse_test_result(test_result_str):
    
    metrics = {}
    for item in test_result_str.strip().split(','):
        key, value = item.split(':')
        metrics[key.strip()] = float(value.strip())
    return metrics

def collect_results(root_dir):
    
    data = []
    
    for runner_name in os.listdir(root_dir):
        runner_path = os.path.join(root_dir, runner_name)
        if not os.path.isdir(runner_path):
            continue
        print(runner_path)
        for model_name in os.listdir(runner_path):
            model_path = os.path.join(runner_path, model_name)
            if not os.path.isdir(model_path):
                continue
            print(model_path)
            for ex_id in os.listdir(model_path):
                ex_id_path = os.path.join(model_path, ex_id)
                if not os.path.isdir(ex_id_path):
                    continue
                print(ex_id_path)
                # 
                json_path = os.path.join(ex_id_path, 'result.json')
                if not os.path.exists(json_path):
                    continue
                print(json_path)
                # JSON
                try:
                    with open(json_path, 'r', encoding='utf-8') as f:
                        results = json.load(f)
                        test_result = parse_test_result(results['test_result'])
                        
                        # 
                        test_record = {
                            'total_time': results.get('total_time',''),
                            'best_val_epoch': results['best_val_epoch'],
                            'runner': runner_name,
                            'model': model_name,
                            'ex_id': ex_id,
                            **test_result
                        }
                        data.append(test_record)
                except Exception as e:
                    print(f"Error processing {json_path}: {str(e)}")
    
    return data

def save_to_excel(data, root_dir):
    """Excel"""
    if not data:
        print("No data found to save.")
        return

    output_path = os.path.join(root_dir, 'results.xlsx')
    df = pd.DataFrame(data)
    
    columns = [
        # 'runner',
        'model', 'ex_id','best_val_epoch','total_time'] + METRICS_ORDER
    df = df[columns].astype(str)

    df.to_excel(output_path, index=False, float_format="%.4f")
    print(f"Results saved to: {output_path}")

# %%
dataset = "PersonalWAB"
base_dir = f'output/{dataset}'

save_to_excel(collect_results(base_dir), base_dir)
# Out:
# output/PersonalWAB/TEM_SrcRunner_0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/TEM_SrcRunner_0-qwen2.5Emb-lr_scheduler/checkpoints
# output/PersonalWAB/TEM_SrcRunner_0-qwen2.5Emb-lr_scheduler/checkpoints/20250202-173622
# output/PersonalWAB/SrcRunner
# output/PersonalWAB/SrcRunner/TEM
# output/PersonalWAB/SrcRunner/TEM/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/AEM
# output/PersonalWAB/SrcRunner/AEM/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/AEM/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/AEM/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/AEM/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/HEM
# output/PersonalWAB/SrcRunner/HEM/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/HEM/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/HEM/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/HEM/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/QEM
# output/PersonalWAB/SrcRunner/QEM/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/QEM/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/QEM/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/QEM/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/ZAM
# output/PersonalWAB/SrcRunner/ZAM/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/ZAM/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/ZAM/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/ZAM/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/CoPPS
# output/PersonalWAB/SrcRunner/CoPPS/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/CoPPS/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/CoPPS/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/CoPPS/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118
# output/PersonalWAB/SrcRunner/TEM_CS_0118/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/2-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/2-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/3-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/3-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/4-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/4-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/5-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/5-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/4-bugFix-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/4-bugFix-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/5-bugFix-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/5-bugFix-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/0-bugFix-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/0-bugFix-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0118/1-bugFix-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0118/1-bugFix-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204
# output/PersonalWAB/SrcRunner/TEM_CS_0204/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1.cp-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1.cp-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1.cp5e4-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1.cp5e4-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1.cp5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204/1.cp5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/2-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/2-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/3-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/3-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/4-waL118-5e4-info-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/4-waL118-5e4-info-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/5-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0204_QuerySum/5-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/0-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/0-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/1-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/1-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/2-wa118-5e4-info-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/2-wa118-5e4-info-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/4-waL118-5e4-info-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/4-waL118-5e4-info-qwen2.5Emb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/5-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/5-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7-moev1-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7-moev1-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/6-moev1-waL118-5e4-info-qwen2.5Emb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.cp-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.cp-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-wa118-5e4-inforec-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-wa118-5e4-inforec-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-inforec-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-inforec-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-wa118-5e4-infoall-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-wa118-5e4-infoall-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-infoall-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-infoall-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-infosrcv3-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-5e4-infosrcv3-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-1e3-infosrcv3-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-exllm-wa118-1e3-infosrcv3-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-moev1-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-moev1-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/8.iname-moev1-waL118-5e4-infol2-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/8.iname-moev1-waL118-5e4-infol2-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-multiAlign-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/3.iname-multiAlign-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.iname-multiAlign-moev1-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.iname-multiAlign-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.iname-multiAlign-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/8.iname-moev1-exllm-waL118-5e4-infol2-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/8.iname-moev1-exllm-waL118-5e4-infol2-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-AddUser2-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-AddUser2-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.iname-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.iname-multiAlign-AddUser2-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.iname-multiAlign-AddUser2-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.cp.iname-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/7.cp.iname-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.cp.iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.cp.iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.cp2.iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/10.cp2.iname-multiAlign-AddUser3-moev2-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(src_inv_index_v1).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(src_inv_index_v1).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(rec_inv_index_v1).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(rec_inv_index_v1).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(src_inv_index_v4).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(src_inv_index_v5).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(src_inv_index_v5).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(src_inv_index_v6).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9(src_inv_index_v6).iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.(relu)iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.(relu)iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.(prelu)iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.(gelu)iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.(silu)iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum/9.(swiglu)iname-multiAlign-AddUser3-moev1-exllm-waL118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_PredMlp
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_PredMlp/3.iname-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_PredMlp/3.iname-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_PredMlp/4.iname-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_PredMlp/4.iname-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_UserEmb
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_UserEmb/1.iname-AddUser1-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0208_QuerySum_UserEmb/3.iname-AddUser3-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum_UserEmb
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum_UserEmb/2.iname-AddUser2-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum_UserEmb/2.iname-AddUser2-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum_UserEmb/3.iname-AddUser3-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum_UserEmb/3.iname-AddUser3-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum_UserEmb/1.iname-AddUser1-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler
# output/PersonalWAB/SrcRunner/TEM_CS_0206_QuerySum_UserEmb/1.iname-AddUser1-exllm-wa118-5e4-info-noLlmEmb-lr_scheduler/result.json
# Results saved to: output/PersonalWAB/results.xlsx
